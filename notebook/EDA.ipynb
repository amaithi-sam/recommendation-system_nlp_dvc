# %% [markdown]
# Importing required libraries

# %%
import pandas as pd 
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"..\data\BigBasket Products.csv", index_col='index')

# %%
df.head()
# Out:
#                                                  product  \
# index
# 1                 Garlic Oil - Vegetarian Capsule 500 mg
# 2                                  Water Bottle - Orange
# 3                         Brass Angle Deep - Plain, No.2
# 4      Cereal Flip Lid Container/Storage Jar - Assort...
# 5                     Creme Soft Soap - For Hands & Body
#
#                      category           sub_category              brand  \
# index
# 1            Beauty & Hygiene              Hair Care  Sri Sri Ayurveda
# 2      Kitchen, Garden & Pets  Storage & Accessories         Mastercook
# 3        Cleaning & Household            Pooja Needs                Trm
# 4        Cleaning & Household   Bins & Bathroom Ware             Nakoda
# 5            Beauty & Hygiene       Bath & Hand Wash              Nivea
#
#        sale_price  market_price                      type  rating  \
# index
# 1           220.0         220.0          Hair Oil & Serum     4.1
# 2           180.0         180.0    Water & Fridge Bottles     2.3
# 3           119.0         250.0           Lamp & Lamp Oil     3.4
# 4           149.0         176.0  Laundry, Storage Baskets     3.7
# 5           162.0         162.0      Bathing Bars & Soaps     4.4
#
#                                              description
# index
# 1      This Product contains Garlic Oil that is known...
# 2      Each product is microwave safe (without lid), ...
# 3      A perfect gift for all occasions, be it your m...
# 4      Multipurpose container with an attractive desi...
# 5      Nivea Creme Soft Soap gives your skin the best...

# %%
df.shape
# Out:
# (27555, 9)

# %%
df.describe()
# Out:
#          sale_price  market_price        rating
# count  27555.000000  27555.000000  18929.000000
# mean     322.514808    382.056664      3.943410
# std      486.263116    581.730717      0.739063
# min        2.450000      3.000000      1.000000
# 25%       95.000000    100.000000      3.700000
# 50%      190.000000    220.000000      4.100000
# 75%      359.000000    425.000000      4.300000
# max    12500.000000  12500.000000      5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27555 entries, 1 to 27555
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product       27554 non-null  object
#  1   category      27555 non-null  object
#  2   sub_category  27555 non-null  object
#  3   brand         27554 non-null  object
#  4   sale_price    27555 non-null  float64
#  5   market_price  27555 non-null  float64
#  6   type          27555 non-null  object
#  7   rating        18929 non-null  float64
#  8   description   27440 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 2.1+ MB

# %%
# missing values
df.isnull().sum()
# Out:
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         0
# market_price       0
# type               0
# rating          8626
# description      115
# dtype: int64

# %%
print('Null percentage for each column', end="\n\n")

total_count = df.shape[0]

for col in df.columns:
    null_count = df[col].isnull().sum()
    print("{} : {:.2f}".format(col, null_count/total_count * 100))
# Out:
# Null percentage for each column
#
# product : 0.00
# category : 0.00
# sub_category : 0.00
# brand : 0.00
# sale_price : 0.00
# market_price : 0.00
# type : 0.00
# rating : 31.30
# description : 0.42

# %%
print('total null data')
null_count = df.isnull().sum().sum()

total_count = df.size 

print("{:.2f}".format(null_count/total_count * 100))
# Out:
# total null data
# 3.53

# %% [markdown]
# drop the missing data

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# product         0
# category        0
# sub_category    0
# brand           0
# sale_price      0
# market_price    0
# type            0
# rating          0
# description     0
# dtype: int64

# %%
df.head()
# Out:
#                                                  product  \
# index
# 1                 Garlic Oil - Vegetarian Capsule 500 mg
# 2                                  Water Bottle - Orange
# 3                         Brass Angle Deep - Plain, No.2
# 4      Cereal Flip Lid Container/Storage Jar - Assort...
# 5                     Creme Soft Soap - For Hands & Body
#
#                      category           sub_category              brand  \
# index
# 1            Beauty & Hygiene              Hair Care  Sri Sri Ayurveda
# 2      Kitchen, Garden & Pets  Storage & Accessories         Mastercook
# 3        Cleaning & Household            Pooja Needs                Trm
# 4        Cleaning & Household   Bins & Bathroom Ware             Nakoda
# 5            Beauty & Hygiene       Bath & Hand Wash              Nivea
#
#        sale_price  market_price                      type  rating  \
# index
# 1           220.0         220.0          Hair Oil & Serum     4.1
# 2           180.0         180.0    Water & Fridge Bottles     2.3
# 3           119.0         250.0           Lamp & Lamp Oil     3.4
# 4           149.0         176.0  Laundry, Storage Baskets     3.7
# 5           162.0         162.0      Bathing Bars & Soaps     4.4
#
#                                              description
# index
# 1      This Product contains Garlic Oil that is known...
# 2      Each product is microwave safe (without lid), ...
# 3      A perfect gift for all occasions, be it your m...
# 4      Multipurpose container with an attractive desi...
# 5      Nivea Creme Soft Soap gives your skin the best...

# %%
cat_column = df.select_dtypes(include='object')

# %%
for col in cat_column.columns:
    print(f" {col} : {cat_column[col].unique()}", end='\n\n')
# Out:
#  product : ['Garlic Oil - Vegetarian Capsule 500 mg' 'Water Bottle - Orange'
#  'Brass Angle Deep - Plain, No.2' ...
#  'Wottagirl! Perfume Spray - Heaven, Classic'
#  'Peri-Peri Sweet Potato Chips' 'Green Tea - Pure Original']
#
#  category : ['Beauty & Hygiene' 'Kitchen, Garden & Pets' 'Cleaning & Household'
#  'Gourmet & World Food' 'Foodgrains, Oil & Masala'
#  'Snacks & Branded Foods' 'Beverages' 'Bakery, Cakes & Dairy' 'Baby Care']
#
#  sub_category : ['Hair Care' 'Storage & Accessories' 'Pooja Needs' 'Bins & Bathroom Ware'
#  'Bath & Hand Wash' 'All Purpose Cleaners' 'Skin Care'
#  'Mops, Brushes & Scrubs' 'Cooking & Baking Needs' 'Chocolates & Biscuits'
#  'Fresheners & Repellents' 'Snacks, Dry Fruits, Nuts' 'Dairy & Cheese'
#  'Pasta, Soup & Noodles' 'Dry Fruits' 'Drinks & Beverages'
#  'Kitchen Accessories' 'Flask & Casserole' 'Breakfast Cereals'
#  'Frozen Veggies & Snacks' 'Fruit Juices & Drinks' 'Cookies, Rusk & Khari'
#  'Fragrances & Deos' 'Tea' 'Masalas & Spices' "Men's Grooming"
#  'Chocolates & Candies' 'Steel Utensils' 'Tinned & Processed Food'
#  'Organic Staples' 'Sauces, Spreads & Dips' 'Pickles & Chutney'
#  'Ready To Cook & Eat' 'Baby Bath & Hygiene' 'Pet Food & Accessories'
#  'Biscuits & Cookies' 'Oral Care' 'Snacks & Namkeen'
#  'Cookware & Non Stick' 'Dairy' 'Diapers & Wipes' 'Baby Food & Formula'
#  'Edible Oils & Ghee' 'Crockery & Cutlery' 'Oils & Vinegar'
#  'Feminine Hygiene' 'Feeding & Nursing' 'Stationery'
#  'Energy & Soft Drinks' 'Appliances & Electricals' 'Salt, Sugar & Jaggery'
#  'Gourmet Breads' 'Indian Mithai' 'Health & Medicine'
#  'Disposables, Garbage Bag' 'Noodle, Pasta, Vermicelli' 'Dals & Pulses'
#  'Rice & Rice Products' 'Spreads, Sauces, Ketchup' 'Cereals & Breakfast'
#  'Party & Festive Needs' 'Health Drink, Supplement' 'Non Dairy' 'Bakeware'
#  'Baby Accessories' 'Coffee' 'Makeup' 'Detergents & Dishwash'
#  'Atta, Flours & Sooji' 'Car & Shoe Care' 'Cakes & Pastries' 'Gardening'
#  'Ice Creams & Desserts' 'Water' 'Mothers & Maternity' 'Bakery Snacks'
#  'Cuts & Sprouts']
#
#  brand : ['Sri Sri Ayurveda ' 'Mastercook' 'Trm' ... 'Ganesh' 'Baron De Bercy'
#  '4700BC']
#
#  type : ['Hair Oil & Serum' 'Water & Fridge Bottles' 'Lamp & Lamp Oil'
#  'Laundry, Storage Baskets' 'Bathing Bars & Soaps'
#  'Disinfectant Spray & Cleaners' 'Face Care' 'Hand Wash & Sanitizers'
#  'Shampoo & Conditioner' 'Utensil Scrub-Pad, Glove' 'Flours & Pre-Mixes'
#  'Luxury Chocolates, Gifts' 'Floor & Other Cleaners' 'Mosquito Repellent'
#  'Soap Cases & Dispensers' 'Aromatherapy' 'Roasted Seeds & Nuts' 'Tofu'
#  'Tools & Accessories' 'Imported Noodles' 'Other Dry Fruits'
#  'Gourmet Tea & Tea Bags' 'Choppers & Graters' 'Casserole'
#  'Granola & Cereal Bars' 'Frozen Veg Snacks' 'Lip Care' 'Juices'
#  'Bakery Biscuits, Cookies' "Men's Deodorants" 'Green Tea'
#  'Containers Sets' 'Whole Spices' 'Blended Masalas' 'Chocolates'
#  'Eau De Toilette' 'Cookies, Biscotti, Wafer' 'Steel Lunch Boxes'
#  'Olive, Jalapeno, Gherkin' 'Organic Rice, Other Rice' 'Shaving Care'
#  'Imported Cleaners' 'Thai & Asian Sauces' 'Chutney Powder'
#  'Cooking Pastes' 'Gourmet Juices & Drinks' 'Face & Body' 'Beans & Pulses'
#  'Papads, Ready To Fry' 'Hair & Scalp Treatment' 'Baby Health'
#  'Kitchen Tools & Other Accessories' 'Pet Meals & Treats'
#  'Chocolate, Peanut Spread' 'Marie, Health, Digestive'
#  'Electric Toothbrush' 'Toothpaste' 'Toothbrush' 'Chips & Corn Snacks'
#  'Organic Dals & Pulses' 'Agarbatti, Incense Sticks' 'Tawa & Sauce Pan'
#  'Flavoured, Soya Milk' 'Namkeen & Savoury Snacks'
#  'Steel Storage Containers' 'Diapers' 'Shower Gel & Body Wash' 'Umbrella'
#  'Kadai & Fry Pans' 'Baby Food' 'Body Care' 'Organic Masalas & Spices'
#  'Leaf & Dust Tea' 'Rusks' 'Air Freshener' 'Lunch Boxes'
#  'Sunflower, Rice Bran Oil' 'Cream Biscuits & Wafers' 'Glassware'
#  'Breakfast & Snack Mixes' 'Plates & Tumblers' 'Organic Edible Oil, Ghee'
#  'Lime & Mango Pickle' 'Powdered Spices' 'Flakes' 'Flavoured & Other Oils'
#  'Hair Removal' 'Pure, Pomace Olive Oil' 'Hair Color' 'Bibs & Napkins'
#  'Exam Pads & Pencil Box' 'Sports & Energy Drinks' 'CFL & Led Bulbs'
#  'Sugar & Jaggery' 'Heat & Eat Ready Meals' 'Gourmet Bread'
#  'Notebooks, Files, Folders' 'Chikki & Gajjak' 'Home Baking'
#  'Strainer, Ladle, Spatula' 'Balsamic & Cider Vinegar' 'Baby Wipes'
#  'Dustbins' 'Pressure Cookers' 'Supplements & Proteins'
#  'Herbs, Seasonings & Rubs' 'Paneer, Tofu & Cream' 'Nachos & Chips'
#  'Exotic Sugar & Salt' 'Salted Biscuits' 'Marshmallow, Candy, Jelly'
#  'Cotton & Ear Buds' 'Health Drinks' 'Frozen Vegetables'
#  'Curry Paste, Coconut Milk' 'Paper Napkin, Tissue Box' 'Instant Noodles'
#  'Cereals & Millets' 'Basmati Rice' 'Cook And Serve' 'Cold Drinks'
#  'Dinner Sets' 'Tea Bags' 'Oats & Porridge' 'Copper Utensils'
#  'Salad Dressings' 'Cereal & Granola Bars' 'Organic Baby Food'
#  'Chilli & Soya Sauce' 'Bowls & Vessels' 'Other Veg Pickle' 'Muesli'
#  'Tomatoes & Vegetables' 'Crackers & Digestive' 'Kids Cereal'
#  'Toilet Cleaners' 'Baking, Cake Decorations' 'Dust Cloth & Wipes'
#  'Ghee & Vanaspati' 'Other Pooja Needs' 'Vacuum Flask'
#  'Choco & Nut Spread' 'Caps, Balloons & Candles' 'Pen, Pencils'
#  'Plates & Bowls' 'Organic & Cold Press Oil' 'Face Masks & Safety Gears'
#  'Eau De Parfum' 'Dessert Mixes' 'Toilet & Other Brushes' 'Organic Flours'
#  'Talc' 'Toffee, Candy & Lollypop' 'Bath Stool, Basin & Sets'
#  'Colours & Crayons' 'Jams, Marmalade, Spreads' 'Sexual Wellness'
#  'Kids (5+Yrs)' 'Milk & Soya Drinks' 'Honey & Maple Syrup'
#  'Pastas & Spaghetti' 'Baking Tools & Brushes' 'Baby Powder'
#  'Other Plastic Ware' 'Cutlery, Spoon & Fork' 'Body Sprays & Mists'
#  'Toilet Paper' 'Mops, Wipers' 'Mouthwash' 'Intimate Wash & Care'
#  'Yogurt & Shrikhand' 'International Chocolates' 'Organic Sugar, Jaggery'
#  'Tomato Ketchup & Sauces' 'Exotic & Flavoured Tea'
#  'Hangers, Clips & Rope' 'Bath & Shower' 'Herbs & Seasoning'
#  'Kitchen, Glass & Drain' "Women's Deodorants" 'Eye Care' 'Honey'
#  'Scissor, Glue & Tape' 'Tinned, Packed Sweets' 'Lighters' 'Garbage Bags'
#  'Everyday Medicine' 'Soothers & Teethers' 'Fresh Sweets'
#  'Mints & Chewing Gum' 'Ground Coffee' 'Perfume'
#  'Toor, Channa & Moong Dal' 'Urad & Other Dals' 'Eyes'
#  'Fabric Pre, Post Wash' 'Cup Noodles' 'Non Veg Pickle'
#  'Frozen Non-Veg Snacks' 'Organic Dry Fruits' 'Mayonnaise'
#  'Bathing Accessories' 'Gingelly Oil' 'Rice & Other Flours'
#  'Infant Formula' 'Shoe Polish' 'Cups, Mugs & Tumblers' 'Cookies'
#  'Buckets & Mugs' 'Soups' 'Sanitary Napkins' 'Detergent Powder, Liquid'
#  'Butter & Cream' 'Kitchen Rolls' 'Extra Virgin Olive Oil' 'Vinegar'
#  'Cheese' 'Muffins & Cup Cakes' 'Gardening Tools' 'Pooja Thali & Bells'
#  'Ice Creams' 'Knives & Peelers' 'Cooking Chocolate, Cocoa'
#  'Jasmine & Sushi Rice' 'Hair Care & Styling' 'Poha, Sabudana & Murmura'
#  'Men & Women' 'Baby Oil & Shampoo' 'Dishwash Bars & Powders'
#  'Pasta & Macaroni' 'Mukhwas' 'Fertilizers & Pesticides'
#  'Brooms & Dust Pans' 'Camphor & Wicks' 'Baby Oral Care'
#  'Frozen Indian Breads' 'Raw Rice' 'Dishwash Liquids & Pastes'
#  'Battery & Electrical' 'Gift Sets' 'Baby Creams & Lotions'
#  'Pots, Planters & Trays' 'Bakeware Accessories' 'Instant Coffee'
#  'Wall Hooks & Hangers' 'Dips & Dressings' 'Curd'
#  'Mustard & Cheese Sauces' 'Tea Cakes & Slice Cakes' 'Baby Bath'
#  'Spring Water' 'Salts' 'Sugarfree Sweeteners' 'Cashews'
#  'Trail & Cocktail Mixes' 'Groundnut Oil' 'Pastries & Brownies'
#  'Soda & Cocktail Mix' 'Tampons & Menstrual Cups' 'Syrups & Concentrates'
#  'Condensed, Powdered Milk' 'Blended Cooking Oils' 'Insect Repellent'
#  'Other Edible Oils' 'Talcum Powder' 'Car Freshener' 'Olive & Canola Oils'
#  'Floss & Tongue Cleaner' 'Car Polish & Cleaners' 'Cookware Sets' 'Face'
#  'Hakka Noodles' 'Panty Liners' 'Eau De Cologne' 'Detergent Bars'
#  'Unsweetened, Cold Press' 'Flavoured & Greek Yogurt'
#  'Disposable Cups & Plates' 'Moustache & Beard Care'
#  'Jam, Conserve, Marmalade' 'Vermicelli' 'Sippers & Bottles'
#  'Khari & Cream Rolls' 'Sooji, Maida & Besan' 'Decorations'
#  'Children (2-5 Yrs)' 'Instant Pasta' 'Games & Calculators'
#  'Pet Cleaning & Grooming' 'Attar' 'Boiled & Steam Rice'
#  'Birthday & Party Cakes' 'Premium Cookies' 'Pet Toys' 'Atta Whole Wheat'
#  'Antiseptics & Bandages' 'Aluminium Foil, Clingwrap'
#  'Candles & Match Box' 'Bath Salts & Oils' 'Organic Millet & Flours'
#  'Maternity Health Supplements' 'Glucose Powder, Tablets' 'Adult Diapers'
#  'Milk' 'Gourmet Flakes' 'Baby Gift Sets' 'Soya & Mustard Oils'
#  'Wet Wipe, Pocket Tissues' 'Glucose & Milk Biscuits' 'Baby Laundry'
#  'Pet Collars & Leashes' 'Butter & Margarine' 'Gift Wraps & Bags'
#  'Baby Dishes & Utensils' 'Pet Feeding Support' 'Racks & Holders'
#  'Non Alcoholic Drinks' 'Bread Sticks & Lavash' 'Dairy Free (Vegan)'
#  'Books & Magazines' 'Almonds' 'Cloth Dryer & Iron Table' 'Packaged Water'
#  'Seeds & Sapling' 'Buttermilk & Lassi' 'Combos & Gift Sets'
#  'Maternity Personal Care' 'Panini, Focaccia & Pita' 'Bagels & Baguette'
#  'Diabetic Drinks' 'Nails' 'Cream & Cheese Spreads'
#  'Regular & White Vinegar' 'Gift Boxes' 'Nursing Tools'
#  'Seasonal Accessories' 'Non-Alcoholic Beer, Wine'
#  'Body Scrubs & Exfoliants' 'Raisins' 'Bakeware Moulds, Cutters'
#  'Icetea, Non Aerated Drink' 'Metal, Furniture Cleaner'
#  'Cheese & Garlic Bread' 'Hair Styling' 'Makeup Accessories'
#  'Erasers & Sharpeners' 'Health Supplements' 'Dry Shampoo & Conditioner'
#  'Wine & Rice Vinegar' 'Combs, Brushes, Clippers' 'Canola & Rapeseed Oil'
#  'Lips' 'Holi Colours & Pichkari' 'Baby Buds' 'Baby Toys'
#  'Nappies & Rash Cream' 'Ayurveda' 'Gourmet Popcorn']
#
#  description : ['This Product contains Garlic Oil that is known to help proper digestion, maintain proper cholesterol levels, support cardiovascular and also build immunity.  For Beauty tips, tricks & more visit https://bigbasket.blog/'
#  'Each product is microwave safe (without lid), refrigerator safe, dishwasher safe and can also be used for re-heating food and not for cooking. All containers come with airtight lids and a wide variety of attractive colours. Stack these stylish and colourful containers in your kitchen with ease and for a look-good factor.'
#  'A perfect gift for all occasions, be it your mother, sister, in-laws, boss or your friends, this beautiful designer piece wherever placed, is sure to beautify the surroundings Traditional design This type diya has been used for Diwali and All other Festivals for centuries. Sturdy and easy to carry The feet keep it balanced to ensure safety. Wonderful Oil Lamp made in Brass also called as Jyoti. This is a handcrafted piece of Indian brass Deepak.'
#  ...
#  'Puramate rosemary is enough to transform a dish into something\r\nextraordinary. It is vibrant , dynamic ,aromatic and a perfect flavor booster.\r\nSprinkle some in your , breads & baked goods , salads, sautéed\xa0vegetables,\r\ncurries, fried rice and even dips and sauces, as well as herbal teas and\r\nseasoning blends and they can lend that instant zing. Pairs well with bay, garlic,\r\nmarjoram, oregano, parsley, sage, savory, and thyme.'
#  'We have taken the richness of Sweet Potatoes (Shakarkand) and given it a spicy delicious Peri Peri twist! The crispiness is unlike anything before and before you know it, you would have finished the whole pack even before the movie introductions would have been over! :p\r\r\n\r\r\nThe best part is that these chips are non-fried, which means they have almost 82% less oil than standard market chips. So yes, you can be on a diet and still relish chips like never before!'
#  'Tetley Green Tea with its refreshing pure, original flavour contains five times more antioxidants than fruits and vegetables. A cup of Tetley Natural Green Tea helps cleanse from within and eliminates all those pollutants and toxins that our bodies are exposed to on a daily basis!! Rejuvenate yourself every day with a cup of Tetley Natural Green Tea.']

# %%
df.to_csv('cleaned_data.csv', index=False)
